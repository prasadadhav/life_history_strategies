# %% [markdown]
# # Loading & Processing data

# %% [markdown]
# ## Load libs

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load data

# %%
anage_df = pd.read_csv('./data/anage_data.txt', sep='\t')

# %%
anage_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4645 entries, 0 to 4644
# Data columns (total 31 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   HAGRID                            4645 non-null   int64
#  1   Kingdom                           4645 non-null   object
#  2   Phylum                            4645 non-null   object
#  3   Class                             4645 non-null   object
#  4   Order                             4645 non-null   object
#  5   Family                            4645 non-null   object
#  6   Genus                             4645 non-null   object
#  7   Species                           4645 non-null   object
#  8   Common name                       4645 non-null   object
#  9   Female maturity (days)            2485 non-null   float64
#  10  Male maturity (days)              1905 non-null   float64
# ...

# %%
anage_df.head()
# Out:
#    HAGRID   Kingdom      Phylum         Class        Order        Family  \
# 0       3  Animalia    Annelida    Polychaeta    Sabellida  Siboglinidae
# 1       5  Animalia    Annelida    Polychaeta    Sabellida  Siboglinidae
# 2       6  Animalia    Annelida    Polychaeta    Sabellida  Siboglinidae
# 3       8  Animalia  Arthropoda     Arachnida      Araneae   Theridiidae
# 4       9  Animalia  Arthropoda  Branchiopoda  Diplostraca    Daphniidae
#
#             Genus    Species                Common name  \
# 0        Escarpia   laminata          Escarpia laminata
# 1  Lamellibrachia    luymesi     Lamellibrachia luymesi
# 2     Seepiophila     jonesi         Seepiophila jonesi
# 3     Latrodectus   hasselti  Australian redback spider
# 4         Daphnia  pulicaria                    Daphnia
#
#    Female maturity (days)  ...  Source  Specimen origin  Sample size  \
# 0                     NaN  ...    1466             wild       medium
# ...

# %%
anage_df.describe()
# Out:
#             HAGRID  Female maturity (days)  Male maturity (days)  \
# count  4645.000000             2485.000000           1905.000000
# mean   2336.170291             1029.443058            940.518635
# std    1346.328818             1656.834711           1020.610062
# min       1.000000                3.000000              3.000000
# 25%    1169.000000              365.000000            365.000000
# 50%    2338.000000              578.000000            639.000000
# 75%    3502.000000             1186.000000           1095.000000
# max    4671.000000            56940.000000           9855.000000
#
#        Gestation/Incubation (days)  Weaning (days)  Litter/Clutch size  \
# count                  1835.000000      768.000000        2.093000e+03
# mean                     88.743869      140.052083        1.449034e+05
# std                     196.460204      162.223798        6.557596e+06
# min                       1.000000        7.000000        1.000000e+00
# ...

# %% [markdown]
# # Explore different datasets

# %%
anage_df.columns
# Out:
# Index(['HAGRID', 'Kingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus',
#        'Species', 'Common name', 'Female maturity (days)',
#        'Male maturity (days)', 'Gestation/Incubation (days)', 'Weaning (days)',
#        'Litter/Clutch size', 'Litters/Clutches per year',
#        'Inter-litter/Interbirth interval', 'Birth weight (g)',
#        'Weaning weight (g)', 'Adult weight (g)', 'Growth rate (1/days)',
#        'Maximum longevity (yrs)', 'Source', 'Specimen origin', 'Sample size',
#        'Data quality', 'IMR (per yr)', 'MRDT (yrs)', 'Metabolic rate (W)',
#        'Body mass (g)', 'Temperature (K)', 'References'],
#       dtype='object')

# %%
anage_df['Class'].unique()
# Out:
# array(['Polychaeta', 'Arachnida', 'Branchiopoda', 'Insecta',
#        'Malacostraca', 'Actinopterygii', 'Amphibia', 'Ascidiacea', 'Aves',
#        'Cephalaspidomorphi', 'Chondrichthyes', 'Chondrostei', 'Cladistei',
#        'Coelacanthi', 'Dipnoi', 'Holostei', 'Mammalia', 'Reptilia',
#        'Teleostei', 'Anthozoa', 'Hydrozoa', 'Echinoidea', 'Bivalvia',
#        'Cephalopoda', 'Gastropoda', 'Chromadorea', 'Rhabditophora',
#        'Trepaxonemata', 'Demospongiae', 'Hexactinellida',
#        'Gammaproteobacteria', 'Pinopsida', 'Magnoliopsida',
#        'Ginkgoopsida', 'Saccharomycetes', 'Schizosaccharomycetes',
#        'Sordariomycetes'], dtype=object)

# %% [markdown]
# ## Class Mammalia

# %%
mammalia_df = anage_df[anage_df['Class'] == 'Mammalia']
print(mammalia_df)
# Out:
#       HAGRID   Kingdom    Phylum     Class          Order           Family  \
# 1874    1888  Animalia  Chordata  Mammalia   Afrosoricida       Tenrecidae
# 1875    1889  Animalia  Chordata  Mammalia   Afrosoricida       Tenrecidae
# 1876    1890  Animalia  Chordata  Mammalia   Afrosoricida       Tenrecidae
# 1877    1891  Animalia  Chordata  Mammalia   Afrosoricida       Tenrecidae
# 1878    1892  Animalia  Chordata  Mammalia   Afrosoricida       Tenrecidae
# ...      ...       ...       ...       ...            ...              ...
# 3218    3238  Animalia  Chordata  Mammalia   Soricomorpha         Talpidae
# 3219    3239  Animalia  Chordata  Mammalia   Soricomorpha         Talpidae
# 3220    3240  Animalia  Chordata  Mammalia   Soricomorpha         Talpidae
# 3221    3241  Animalia  Chordata  Mammalia   Soricomorpha         Talpidae
# 3222    3242  Animalia  Chordata  Mammalia  Tubulidentata  Orycteropodidae
#
#              Genus       Species             Common name  \
# ...

# %% [markdown]
# ## Order Cetacea

# %%
cetacea_df = anage_df[anage_df['Order'] == 'Cetacea']
print(cetacea_df)
# Out:
#       HAGRID   Kingdom    Phylum     Class    Order           Family  \
# 2259    2275  Animalia  Chordata  Mammalia  Cetacea       Balaenidae
# 2260    2276  Animalia  Chordata  Mammalia  Cetacea       Balaenidae
# 2261    2277  Animalia  Chordata  Mammalia  Cetacea       Balaenidae
# 2262    2278  Animalia  Chordata  Mammalia  Cetacea  Balaenopteridae
# 2263    2279  Animalia  Chordata  Mammalia  Cetacea  Balaenopteridae
# 2264    2280  Animalia  Chordata  Mammalia  Cetacea  Balaenopteridae
# 2265    2281  Animalia  Chordata  Mammalia  Cetacea  Balaenopteridae
# 2266    2282  Animalia  Chordata  Mammalia  Cetacea  Balaenopteridae
# 2267    2283  Animalia  Chordata  Mammalia  Cetacea  Balaenopteridae
# 2268    2285  Animalia  Chordata  Mammalia  Cetacea      Delphinidae
# 2269    2286  Animalia  Chordata  Mammalia  Cetacea      Delphinidae
# 2270    2287  Animalia  Chordata  Mammalia  Cetacea      Delphinidae
# 2271    2288  Animalia  Chordata  Mammalia  Cetacea      Delphinidae
# ...
